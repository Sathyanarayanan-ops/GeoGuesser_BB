# %%
# %pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in e:\cv project\cvenv\lib\site-packages (4.8.1.78)Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy>=1.21.2 in e:\cv project\cvenv\lib\site-packages (from opencv-python) (1.26.2)

# %%
import time
import math
import random

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from sklearn.metrics import confusion_matrix
from datetime import timedelta

import os
import glob
import numpy as np
import cv2
from sklearn.utils import shuffle
from keras.layers import Dense, Flatten, Dropout, Conv2D, MaxPooling2D

# %matplotlib inline
# Out:
# WARNING:tensorflow:From e:\CV PROJECT\cvenv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout, BatchNormalization
from keras.callbacks import ModelCheckpoint

# %%
# Number of color channels for the images: 1 channel for gray-scale.
num_channels = 3

# image dimensions (only squares for now)
img_size = 128

# Size of image when flattened to a single dimension
img_size_flat = img_size * img_size * num_channels

# Tuple with height and width of images used to reshape arrays.
img_shape = (img_size, img_size)

# class info
classes = ['Downtown', 'Gables', 'Squires', 'UCB']
num_classes = len(classes)

# batch size
batch_size = 32

# validation split
validation_size = .16

data_path = 'Data'
#test_path = 'Data/test/test/'
checkpoint_dir = "Checkpoint/"

# %% [markdown]
# PREPROCESSING DATASET

# %%
def normalize_images(images):
    new_images = []
    for image in images:
        image = image.astype(np.float32)
        image = np.multiply(image, 1.0 / 255.0)
        new_images.append(image) 
    #print("NEW IMAGES:", new_images)
    return new_images

# %%
def load_data(data_path, image_size, classes):
    images = []
    labels = []
    ids = []
    cls = []

    print('Reading training images')
    for fld in classes:  # assuming data directory has a separate folder for each class, and that each folder is named after the class
        index = classes.index(fld)
        print('Loading {} files (Index: {})'.format(fld, index))
        path = os.path.join(data_path, fld, "*.*")
        files = glob.glob(path)
        
        for fl in files:
            image = cv2.imread(fl)
            if image is None:
                print("Error: Unable to load image")
            else:
                # Perform resizing or other operations here
                pass
            
            image = cv2.resize(image, (image_size, image_size), cv2.INTER_LINEAR)

            images.append(image)
            label = np.zeros(len(classes))
            label[index] = 1.0
            labels.append(label)

            flbase = os.path.basename(fl)
            ids.append(flbase)
            cls.append(fld)

    images = np.array(images)
    #print("IMAGES:", images, "\n", "LABEL:", label, "\n", "IDS:", ids, "\n", "CLASSES:", cls)
    labels = np.array(labels)
    ids = np.array(ids)
    cls = np.array(cls)

    return images, labels, ids, cls





def load_test(test_path, image_size):
    path = os.path.join(test_path, '*g')
    files = sorted(glob.glob(path))

    X_test = []
    X_test_id = []
    print("Reading test images")
    for fl in files:
        flbase = os.path.basename(fl)
        img = cv2.imread(fl)
        img = cv2.resize(img, (image_size, image_size), cv2.INTER_LINEAR)
        X_test.append(img)
        X_test_id.append(flbase)

    X_test = normalize_image(X_test)

    return X_test, X_test_id

# %%
def read_train_sets(data_path, image_size, classes, validation_size=0):

    images, labels, ids, cls = load_data(data_path, image_size, classes)
    images, labels, ids, cls = shuffle(images, labels, ids, cls)  # shuffle the data

    #print("IMAGES:", images)

    if isinstance(validation_size, float):
        validation_size = int(validation_size * images.shape[0])

    validation_images = images[:validation_size]
    validation_labels = labels[:validation_size]
    validation_ids = ids[:validation_size]
    validation_cls = cls[:validation_size]

    train_images = images[validation_size:]
    train_labels = labels[validation_size:]
    train_ids = ids[validation_size:]
    train_cls = cls[validation_size:]
    
    normalized_train_imgs = normalize_images(train_images)
    normalized_valid_imgs = normalize_images(validation_images)
    
    train = {
        "images": normalized_train_imgs,
        "labels": train_labels,
        "ids": train_ids,
        "classes": train_cls,
    }

    validation = {
        "images": normalized_valid_imgs,
        "labels": validation_labels,
        "ids": validation_ids,
        "classes": validation_cls,
    }
    
    return train, validation


def read_test_set(test_path, image_size):
    images, ids = load_test(test_path, image_size)
    return images, ids

# %%
train, validation = read_train_sets(data_path, img_size, classes, validation_size=validation_size)
#test_images, test_ids = read_test_set(test_path, img_size)

print("Size of:")
print("- Training-set:\t\t{}".format(len(train['labels'])))
#print("- Test-set:\t\t{}".format(len(test_images)))
print("- Validation-set:\t{}".format(len(validation['labels'])))
# Out:
# Reading training images
# Loading Downtown files (Index: 0)
# Loading Gables files (Index: 1)
# Loading Squires files (Index: 2)
# Loading UCB files (Index: 3)
# Size of:
# - Training-set:		1556
# - Validation-set:	296

# %% [markdown]
# PLOTTING RANDOM IMAGES

# %%
def plot_images(images, cls_true, cls_pred=None):
    
    if len(images) == 0:
        print("no images to show")
        return 
    else:
        random_indices = random.sample(range(len(images)), min(len(images), 9))
        
    if cls_pred is not None:
        images, cls_true, cls_pred  = zip(*[(images[i], cls_true[i], cls_pred[i]) for i in random_indices])
    else:
        images, cls_true  = zip(*[(images[i], cls_true[i]) for i in random_indices])
    
    # Create figure with 3x3 sub-plots.
    fig, axes = plt.subplots(3, 3)
    fig.subplots_adjust(hspace=0.3, wspace=0.3)

    for i, ax in enumerate(axes.flat):
        # Plot image.
        ax.imshow(images[i].reshape(img_size, img_size, num_channels))

        # Show true and predicted classes.
        if cls_pred is None:
            xlabel = "True: {0}".format(cls_true[i])
        else:
            xlabel = "True: {0}, Pred: {1}".format(cls_true[i], cls_pred[i])

        # Show the classes as the label on the x-axis.
        ax.set_xlabel(xlabel)
        
        # Remove ticks from the plot.
        ax.set_xticks([])
        ax.set_yticks([])
    
    # Ensure the plot is shown correctly with multiple plots
    # in a single Notebook cell.
    plt.show()



# Get some random images and their labels from the train set.
images, cls_true  = train['images'][:10], train['classes'][:10]

# Plot the images and labels using our helper-function above.
plot_images(images=images, cls_true=cls_true)

# %% [markdown]
# CNN MODEL

# %%
# Create a Sequential model
model = Sequential()

# Convolutional layers
model.add(Conv2D(32, kernel_size=(3, 3), input_shape=(img_size, img_size, num_channels), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.0001)))
model.add(MaxPooling2D(pool_size=(3, 3)))

model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.0001)))
model.add(MaxPooling2D(pool_size=(3, 3)))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.0001)))
model.add(MaxPooling2D(pool_size=(3, 3)))

# Flattening layer
model.add(Flatten())

# Dense layer
model.add(Dense(units=128, activation='relu'))

# Dense layer
model.add(Dense(units=64, activation='relu'))

# Output layer
model.add(Dense(num_classes))


optimizer = tf.keras.optimizers.Adam(learning_rate=1e-5)

# Compile the model with binary cross-entropy loss and accuracy metric
model.compile(loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True), optimizer=optimizer, metrics=['accuracy'])

# %%
train['images'] = np.array(train['images'])
validation['images'] = np.array(validation['images'])
train['labels'] = np.array(train['labels'])
validation['labels'] = np.array(validation['labels'])

# %%
# Train the model
model_checkpoint = ModelCheckpoint(filepath='model_test_24-10-2023_01.h5', monitor='val_loss', save_best_only=True, mode='min')


# Train the model with callbacks
history = model.fit(train['images'], train['labels'], validation_data=(validation['images'], validation['labels']), epochs=500, shuffle=True, 
                    batch_size=8, callbacks=[model_checkpoint])


model.save('model_test_1.h5')
# Out:
# Epoch 1/500
# 195/195 [==============================] - 3s 10ms/step - loss: 1.3934 - accuracy: 0.2404 - val_loss: 1.3905 - val_accuracy: 0.2838
# Epoch 2/500
# 195/195 [==============================] - 2s 10ms/step - loss: 1
500
# 195/195 [==============================] - 2s 13ms/step - loss: 0.1210 - accuracy: 0.9724 - val_loss: 0.2761 - val_accuracy: 0.9122
# Epoch 301/500
# 195/195 [==============================] - 2s 13ms/step - loss: 0.1232 - accuracy: 0.9724 - val_loss: 0.2697 - val_accuracy: 0.9020
# Epoch 302/500
# 195/195 [==============================] - 3s 13ms/step - loss: 0.1182 - accuracy: 0.9743 - val_loss: 0.2716 - val_accuracy: 0.9189
# Epoch 303/500
# 195/195 [==============================] - 3s 13ms/step - loss: 0.1160 - accuracy: 0.9769 - val_loss: 0.2820 - val_accuracy: 0.9155
# Epoch 304/500
# 195/195 [==============================] - 3s 13ms/step - loss: 0.1159 - accuracy: 0.9756 - val_loss: 0.2682 - val_accuracy: 0.9020
# Epoch 305/500
# 195/195 [==============================] - 3s 14ms/step - loss: 0.1143 - accuracy: 0.9756 - val_loss: 0.2687 - val_accuracy: 0.9122
# Epoch 306/500
# 195/195 [==============================] - 3s 13ms/step - loss: 0.1160 - accuracy: 0.9743 - val_loss: 0.2739 - val_accuracy: 0.8986
# Epoch 307/500
# 195/195 [==============================] - 3s 13ms/step - loss: 0.1156 - accuracy: 0.9737 - val_loss: 0.2774 - val_accuracy: 0.9223
# Epoch 308/500
# 195/195 [==============================] - 3s 13ms/step - loss: 0.1133 - accuracy: 0.9762 - val_loss: 0.2812 - val_accuracy: 0.9122
# Epoch 309/500
# 195/195 [==============================] - 3s 14ms/step - loss: 0.1122 - accuracy: 0.9749 - val_loss: 0.2668 - val_accuracy: 0.9088
# Epoch 310/500
# 195/195 [==============================] - 3s 14ms/step - loss: 0.1103 - accuracy: 0.9730 - val_loss: 0.2764 - val_accuracy: 0.9155
# Epoch 311/500
# 195/195 [==============================] - 3s 13ms/step - loss: 0.1099 - accuracy: 0.9775 - val_loss: 0.2679 - val_accuracy: 0.9020
# Epoch 312/500
# 195/195 [==============================] - 3s 14ms/step - loss: 0.1116 - accuracy: 0.9737 - val_loss: 0.2756 - val_accuracy: 0.9122
# Epoch 313/500
# 195/195 [==============================] - 3s 14ms/step - loss: 0.1085 - accuracy: 0.9756 - val_loss: 0.2713 - val_accuracy: 0.9257
# Epoch 314/500
# 195/195 [==============================] - 3s 14ms/step - loss: 0.1067 - accuracy: 0.9781 - val_loss: 0.2765 - val_accuracy: 0.9155
# Epoch 315/500
# 195/195 [==============================] - 3s 13ms/step - loss: 0.1060 - accuracy: 0.9769 - val_loss: 0.2691 - val_accuracy: 0.9257
# Epoch 316/500
# 195/195 [==============================] - 3s 14ms/step - loss: 0.1078 - accuracy: 0.9781 - val_loss: 0.2768 - val_accuracy: 0.9155
# Epoch 317/500
# 195/195 [==============================] - 2s 12ms/step - loss: 0.1035 - accuracy: 0.9794 - val_loss: 0.2673 - val_accuracy: 0.9155
# Epoch 318/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.1021 - accuracy: 0.9788 - val_loss: 0.2706 - val_accuracy: 0.9054
# Epoch 319/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.1019 - accuracy: 0.9788 - val_loss: 0.2790 - val_accuracy: 0.9189
# Epoch 320/500
# 195/195 [==============================] - 2s 10ms/step - loss: 0.1036 - accuracy: 0.9749 - val_loss: 0.2747 - val_accuracy: 0.9223
# Epoch 321/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.1008 - accuracy: 0.9788 - val_loss: 0.2965 - val_accuracy: 0.8919
# Epoch 322/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.1015 - accuracy: 0.9769 - val_loss: 0.2836 - val_accuracy: 0.9155
# Epoch 323/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0989 - accuracy: 0.9762 - val_loss: 0.2662 - val_accuracy: 0.9257
# Epoch 324/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0980 - accuracy: 0.9769 - val_loss: 0.2864 - val_accuracy: 0.9122
# Epoch 325/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.1005 - accuracy: 0.9801 - val_loss: 0.2882 - val_accuracy: 0.9223
# Epoch 326/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0994 - accuracy: 0.9756 - val_loss: 0.2940 - val_accuracy: 0.8986
# Epoch 327/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0982 - accuracy: 0.9781 - val_loss: 0.2704 - val_accuracy: 0.9223
# Epoch 328/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0949 - accuracy: 0.9807 - val_loss: 0.2803 - val_accuracy: 0.9155
# Epoch 329/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0960 - accuracy: 0.9814 - val_loss: 0.2672 - val_accuracy: 0.9223
# Epoch 330/500
# ...
# Epoch 392/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0506 - accuracy: 0.9949 - val_loss: 0.2699 - val_accuracy: 0.9257
# Epoch 393/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0493 - accuracy: 0.9974 - val_loss: 0.3109 - val_accuracy: 0.9020
# Epoch 394/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0493 - accuracy: 0.9968 - val_loss: 0.2737 - val_accuracy: 0.9189
# Epoch 395/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0481 - accuracy: 0.9961 - val_loss: 0.2735 - val_accuracy: 0.9257
# Epoch 396/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0481 - accuracy: 0.9981 - val_loss: 0.2695 - val_accuracy: 0.9189
# Epoch 397/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0472 - accuracy: 0.9949 - val_loss: 0.2671 - val_accuracy: 0.9155
# Epoch 398/500
# 195/195 [==============================] - 2s 12ms/step - loss: 0.0462 - accuracy: 0.9981 - val_loss: 0.2842 - val_accuracy: 0.9155
# Epoch 399/500
# 195/195 [==============================] - 2s 13ms/step - loss: 0.0458 - accuracy: 0.9981 - val_loss: 0.2923 - val_accuracy: 0.9223
# Epoch 400/500
# 195/195 [==============================] - 2s 13ms/step - loss: 0.0447 - accuracy: 0.9981 - val_loss: 0.2814 - val_accuracy: 0.9122
# Epoch 401/500
# 195/195 [==============================] - 2s 13ms/step - loss: 0.0460 - accuracy: 0.9949 - val_loss: 0.2770 - val_accuracy: 0.9223
# Epoch 402/500
# 195/195 [==============================] - 2s 13ms/step - loss: 0.0449 - accuracy: 0.9968 - val_loss: 0.2815 - val_accuracy: 0.9122
# Epoch 403/500
# 195/195 [==============================] - 3s 13ms/step - loss: 0.0449 - accuracy: 0.9974 - val_loss: 0.2807 - val_accuracy: 0.9122
# Epoch 404/500
# 195/195 [==============================] - 3s 14ms/step - loss: 0.0445 - accuracy: 0.9974 - val_loss: 0.2807 - val_accuracy: 0.9155
# Epoch 405/500
# 195/195 [==============================] - 3s 13ms/step - loss: 0.0424 - accuracy: 0.9987 - val_loss: 0.2763 - val_accuracy: 0.9223
# Epoch 406/500
# 195/195 [==============================] - 3s 13ms/step - loss: 0.0439 - accuracy: 0.9974 - val_loss: 0.2672 - val_accuracy: 0.9155
# Epoch 407/500
# 195/195 [==============================] - 3s 13ms/step - loss: 0.0434 - accuracy: 0.9968 - val_loss: 0.2880 - val_accuracy: 0.9155
# Epoch 408/500
# 195/195 [==============================] - 3s 14ms/step - loss: 0.0412 - accuracy: 0.9974 - val_loss: 0.2988 - val_accuracy: 0.9020
# Epoch 409/500
# 195/195 [==============================] - 3s 13ms/step - loss: 0.0407 - accuracy: 0.9981 - val_loss: 0.3145 - val_accuracy: 0.9020
# Epoch 410/500
# 195/195 [==============================] - 3s 14ms/step - loss: 0.0412 - accuracy: 0.9981 - val_loss: 0.2697 - val_accuracy: 0.9189
# Epoch 411/500
# 195/195 [==============================] - 3s 14ms/step - loss: 0.0393 - accuracy: 0.9981 - val_loss: 0.3430 - val_accuracy: 0.8919
# Epoch 412/500
# 195/195 [==============================] - 3s 13ms/step - loss: 0.0419 - accuracy: 0.9981 - val_loss: 0.2764 - val_accuracy: 0.9189
# Epoch 413/500
# 195/195 [==============================] - 3s 13ms/step - loss: 0.0403 - accuracy: 0.9981 - val_loss: 0.3082 - val_accuracy: 0.9054
# Epoch 414/500
# 195/195 [==============================] - 3s 14ms/step - loss: 0.0386 - accuracy: 0.9994 - val_loss: 0.3016 - val_accuracy: 0.9054
# Epoch 415/500
# 195/195 [==============================] - 3s 14ms/step - loss: 0.0397 - accuracy: 0.9987 - val_loss: 0.2765 - val_accuracy: 0.9189
# Epoch 416/500
# 195/195 [==============================] - 3s 14ms/step - loss: 0.0373 - accuracy: 0.9981 - val_loss: 0.2935 - val_accuracy: 0.9054
# Epoch 417/500
# 195/195 [==============================] - 3s 13ms/step - loss: 0.0379 - accuracy: 0.9987 - val_loss: 0.2904 - val_accuracy: 0.9155
# Epoch 418/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0372 - accuracy: 0.9981 - val_loss: 0.2797 - val_accuracy: 0.9189
# Epoch 419/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0395 - accuracy: 0.9974 - val_loss: 0.2977 - val_accuracy: 0.9122
# Epoch 420/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0363 - accuracy: 0.9987 - val_loss: 0.2818 - val_accuracy: 0.9189
# Epoch 421/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0355 - accuracy: 0.9987 - val_loss: 0.2733 - val_accuracy: 0.9155
# Epoch 422/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0359 - accuracy: 0.9987 - val_loss: 0.2712 - val_accuracy: 0.9155
# Epoch 423/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0350 - accuracy: 0.9987 - val_loss: 0.2867 - val_accuracy: 0.9155
# Epoch 424/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0359 - accuracy: 0.9994 - val_loss: 0.2872 - val_accuracy: 0.9122
# Epoch 425/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0358 - accuracy: 0.9987 - val_loss: 0.2790 - val_accuracy: 0.9291
# Epoch 426/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0330 - accuracy: 0.9994 - val_loss: 0.3130 - val_accuracy: 0.8986
# Epoch 427/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0338 - accuracy: 0.9994 - val_loss: 0.2751 - val_accuracy: 0.9155
# Epoch 428/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0330 - accuracy: 0.9987 - val_loss: 0.2795 - val_accuracy: 0.9189
# Epoch 429/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0336 - accuracy: 0.9987 - val_loss: 0.2805 - val_accuracy: 0.9189
# Epoch 430/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0342 - accuracy: 0.9994 - val_loss: 0.2904 - val_accuracy: 0.9155
# Epoch 431/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0340 - accuracy: 0.9994 - val_loss: 0.2870 - val_accuracy: 0.9189
# Epoch 432/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0330 - accuracy: 0.9981 - val_loss: 0.3420 - val_accuracy: 0.8953
# Epoch 433/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0329 - accuracy: 0.9994 - val_loss: 0.2848 - val_accuracy: 0.9189
# Epoch 434/500
# 195/195 [==============================] - 2s 12ms/step - loss: 0.0315 - accuracy: 0.9994 - val_loss: 0.2844 - val_accuracy: 0.9257
# Epoch 435/500
# 195/195 [==============================] - 2s 13ms/step - loss: 0.0311 - accuracy: 1.0000 - val_loss: 0.2973 - val_accuracy: 0.9088
# Epoch 436/500
# 195/195 [==============================] - 2s 13ms/step - loss: 0.0313 - accuracy: 0.9994 - val_loss: 0.2787 - val_accuracy: 0.9189
# Epoch 437/500
# 195/195 [==============================] - 3s 13ms/step - loss: 0.0297 - accuracy: 0.9987 - val_loss: 0.2936 - val_accuracy: 0.9122
# Epoch 438/500
# 195/195 [==============================] - 3s 13ms/step - loss: 0.0300 - accuracy: 0.9987 - val_loss: 0.2912 - val_accuracy: 0.9189
# Epoch 439/500
# 195/195 [==============================] - 3s 13ms/step - loss: 0.0294 - accuracy: 1.0000 - val_loss: 0.3155 - val_accuracy: 0.9054
# Epoch 440/500
# 195/195 [==============================] - 3s 13ms/step - loss: 0.0283 - accuracy: 0.9994 - val_loss: 0.2920 - val_accuracy: 0.9155
# Epoch 441/500
# 195/195 [==============================] - 3s 13ms/step - loss: 0.0298 - accuracy: 0.9994 - val_loss: 0.2994 - val_accuracy: 0.9122
# Epoch 442/500
# 195/195 [==============================] - 3s 14ms/step - loss: 0.0281 - accuracy: 0.9994 - val_loss: 0.2812 - val_accuracy: 0.9189
# Epoch 443/500
# 195/195 [==============================] - 3s 14ms/step - loss: 0.0277 - accuracy: 0.9994 - val_loss: 0.2863 - val_accuracy: 0.9223
# Epoch 444/500
# 195/195 [==============================] - 3s 14ms/step - loss: 0.0276 - accuracy: 0.9994 - val_loss: 0.3000 - val_accuracy: 0.9122
# Epoch 445/500
# 195/195 [==============================] - 3s 14ms/step - loss: 0.0270 - accuracy: 0.9994 - val_loss: 0.3090 - val_accuracy: 0.9054
# Epoch 446/500
# 195/195 [==============================] - 3s 14ms/step - loss: 0.0265 - accuracy: 0.9994 - val_loss: 0.2994 - val_accuracy: 0.9189
# Epoch 447/500
# 195/195 [==============================] - 3s 14ms/step - loss: 0.0263 - accuracy: 0.9987 - val_loss: 0.2838 - val_accuracy: 0.9189
# Epoch 448/500
# 195/195 [==============================] - 3s 14ms/step - loss: 0.0263 - accuracy: 0.9994 - val_loss: 0.2961 - val_accuracy: 0.9189
# Epoch 449/500
# 195/195 [==============================] - 3s 13ms/step - loss: 0.0266 - accuracy: 0.9994 - val_loss: 0.2920 - val_accuracy: 0.9223
# Epoch 450/500
# 195/195 [==============================] - 3s 13ms/step - loss: 0.0263 - accuracy: 1.0000 - val_loss: 0.3015 - val_accuracy: 0.9189
# Epoch 451/500
# 195/195 [==============================] - 3s 14ms/step - loss: 0.0257 - accuracy: 0.9994 - val_loss: 0.3021 - val_accuracy: 0.9088
# Epoch 452/500
# 195/195 [==============================] - 3s 14ms/step - loss: 0.0249 - accuracy: 1.0000 - val_loss: 0.2924 - val_accuracy: 0.9223
# Epoch 453/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0247 - accuracy: 0.9994 - val_loss: 0.3181 - val_accuracy: 0.9054
# Epoch 454/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0249 - accuracy: 0.9994 - val_loss: 0.3232 - val_accuracy: 0.9054
# Epoch 455/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0246 - accuracy: 1.0000 - val_loss: 0.2924 - val_accuracy: 0.9223
# Epoch 456/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0267 - accuracy: 0.9987 - val_loss: 0.2936 - val_accuracy: 0.9189
# Epoch 457/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0239 - accuracy: 1.0000 - val_loss: 0.2974 - val_accuracy: 0.9223
# Epoch 458/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0230 - accuracy: 1.0000 - val_loss: 0.2928 - val_accuracy: 0.9189
# Epoch 459/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0233 - accuracy: 1.0000 - val_loss: 0.3294 - val_accuracy: 0.9020
# Epoch 460/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0233 - accuracy: 1.0000 - val_loss: 0.2958 - val_accuracy: 0.9223
# Epoch 461/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0228 - accuracy: 1.0000 - val_loss: 0.2966 - val_accuracy: 0.9223
# Epoch 462/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0224 - accuracy: 0.9994 - val_loss: 0.3142 - val_accuracy: 0.9122
# Epoch 463/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0234 - accuracy: 1.0000 - val_loss: 0.3304 - val_accuracy: 0.9155
# Epoch 464/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0223 - accuracy: 1.0000 - val_loss: 0.3025 - val_accuracy: 0.9189
# Epoch 465/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0219 - accuracy: 0.9994 - val_loss: 0.2962 - val_accuracy: 0.9189
# Epoch 466/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0223 - accuracy: 1.0000 - val_loss: 0.3031 - val_accuracy: 0.9257
# Epoch 467/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0217 - accuracy: 1.0000 - val_loss: 0.3380 - val_accuracy: 0.8986
# Epoch 468/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0210 - accuracy: 1.0000 - val_loss: 0.2989 - val_accuracy: 0.9189
# Epoch 469/500
# 195/195 [==============================] - 2s 12ms/step - loss: 0.0203 - accuracy: 1.0000 - val_loss: 0.3050 - val_accuracy: 0.9189
# Epoch 470/500
# 195/195 [==============================] - 3s 14ms/step - loss: 0.0214 - accuracy: 1.0000 - val_loss: 0.2939 - val_accuracy: 0.9155
# Epoch 471/500
# 195/195 [==============================] - 3s 13ms/step - loss: 0.0204 - accuracy: 1.0000 - val_loss: 0.3141 - val_accuracy: 0.9088
# Epoch 472/500
# 195/195 [==============================] - 3s 14ms/step - loss: 0.0209 - accuracy: 1.0000 - val_loss: 0.3114 - val_accuracy: 0.9189
# Epoch 473/500
# 195/195 [==============================] - 3s 14ms/step - loss: 0.0201 - accuracy: 1.0000 - val_loss: 0.3232 - val_accuracy: 0.9088
# Epoch 474/500
# 195/195 [==============================] - 3s 13ms/step - loss: 0.0199 - accuracy: 1.0000 - val_loss: 0.3087 - val_accuracy: 0.9223
# Epoch 475/500
# 195/195 [==============================] - 3s 13ms/step - loss: 0.0194 - accuracy: 1.0000 - val_loss: 0.3181 - val_accuracy: 0.9122
# Epoch 476/500
# 195/195 [==============================] - 3s 13ms/step - loss: 0.0196 - accuracy: 1.0000 - val_loss: 0.3103 - val_accuracy: 0.9257
# Epoch 477/500
# 195/195 [==============================] - 3s 13ms/step - loss: 0.0195 - accuracy: 1.0000 - val_loss: 0.3197 - val_accuracy: 0.9223
# Epoch 478/500
# 195/195 [==============================] - 3s 14ms/step - loss: 0.0192 - accuracy: 1.0000 - val_loss: 0.3130 - val_accuracy: 0.9257
# Epoch 479/500
# 195/195 [==============================] - 3s 15ms/step - loss: 0.0193 - accuracy: 1.0000 - val_loss: 0.3077 - val_accuracy: 0.9223
# Epoch 480/500
# 195/195 [==============================] - 3s 15ms/step - loss: 0.0187 - accuracy: 1.0000 - val_loss: 0.3022 - val_accuracy: 0.9223
# Epoch 481/500
# 195/195 [==============================] - 3s 14ms/step - loss: 0.0184 - accuracy: 1.0000 - val_loss: 0.3087 - val_accuracy: 0.9257
# Epoch 482/500
# 195/195 [==============================] - 3s 14ms/step - loss: 0.0185 - accuracy: 1.0000 - val_loss: 0.3156 - val_accuracy: 0.9155
# Epoch 483/500
# 195/195 [==============================] - 3s 14ms/step - loss: 0.0178 - accuracy: 1.0000 - val_loss: 0.3026 - val_accuracy: 0.9257
# Epoch 484/500
# 195/195 [==============================] - 3s 14ms/step - loss: 0.0176 - accuracy: 1.0000 - val_loss: 0.3294 - val_accuracy: 0.9088
# Epoch 485/500
# 195/195 [==============================] - 3s 14ms/step - loss: 0.0175 - accuracy: 1.0000 - val_loss: 0.3244 - val_accuracy: 0.9155
# Epoch 486/500
# 195/195 [==============================] - 2s 12ms/step - loss: 0.0170 - accuracy: 1.0000 - val_loss: 0.3066 - val_accuracy: 0.9189
# Epoch 487/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0173 - accuracy: 1.0000 - val_loss: 0.3328 - val_accuracy: 0.9122
# Epoch 488/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0175 - accuracy: 1.0000 - val_loss: 0.3189 - val_accuracy: 0.9189
# Epoch 489/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0174 - accuracy: 1.0000 - val_loss: 0.3446 - val_accuracy: 0.9088
# Epoch 490/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0161 - accuracy: 1.0000 - val_loss: 0.3179 - val_accuracy: 0.9223
# Epoch 491/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0168 - accuracy: 1.0000 - val_loss: 0.3165 - val_accuracy: 0.9189
# Epoch 492/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0166 - accuracy: 1.0000 - val_loss: 0.3173 - val_accuracy: 0.9189
# Epoch 493/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0158 - accuracy: 1.0000 - val_loss: 0.3164 - val_accuracy: 0.9189
# Epoch 494/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0156 - accuracy: 1.0000 - val_loss: 0.3223 - val_accuracy: 0.9189
# Epoch 495/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0160 - accuracy: 1.0000 - val_loss: 0.3224 - val_accuracy: 0.9189
# Epoch 496/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0157 - accuracy: 1.0000 - val_loss: 0.3330 - val_accuracy: 0.9122
# Epoch 497/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0154 - accuracy: 1.0000 - val_loss: 0.3210 - val_accuracy: 0.9189
# Epoch 498/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0150 - accuracy: 1.0000 - val_loss: 0.3103 - val_accuracy: 0.9189
# Epoch 499/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0156 - accuracy: 1.0000 - val_loss: 0.3141 - val_accuracy: 0.9189
# Epoch 500/500
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0157 - accuracy: 1.0000 - val_loss: 0.3453 - val_accuracy: 0.9122

# %%
print(len(train['images']))
print(len(train['labels']))
print(len(validation['images']))
print(len(validation['labels']))
# Out:
# 1556
# 1556
# 296
# 296

# %%
# TRAINING LOSS CURVE

plt.plot(history.history['loss'], label='Training loss')

plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# TRAINING AND VALIDATION LOSS CURVE

plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
